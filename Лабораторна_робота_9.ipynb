# %% [markdown]
# <a href="https://colab.research.google.com/github/Valentyna180/structure_task/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0_%D1%80%D0%BE%D0%B1%D0%BE%D1%82%D0%B0_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot_20250421-230023.png](data:image/png;base64,...)

# %%
students = [
    {"піп": "Іван Петренко", "курс": 1, "група": "1-СОМ", "оцінки": {
        "Вища математика": 95, "Аналітична геометрія": 92, "Історія України": 88, "Інформатика": 90, "Іноземна мова": 93}},
    {"піп": "Олена Коваль", "курс": 2, "група": "2-СОМ", "оцінки": {
        "Вища математика": 70, "Аналітична геометрія": 85, "Історія України": 78, "Інформатика": 80, "Іноземна мова": 76}},
    {"піп": "Микита Шевченко", "курс": 3, "група": "1-СОМ", "оцінки": {
        "Вища математика": 98, "Аналітична геометрія": 96, "Історія України": 94, "Інформатика": 99, "Іноземна мова": 97}},
    {"піп": "Анастасія Бондар", "курс": 2, "група": "3-СОМ", "оцінки": {
        "Вища математика": 89, "Аналітична геометрія": 91, "Історія України": 93, "Інформатика": 95, "Іноземна мова": 90}},
    {"піп": "Сергій Дяченко", "курс": 1, "група": "1-СОМ", "оцінки": {
        "Вища математика": 80, "Аналітична геометрія": 75, "Історія України": 82, "Інформатика": 77, "Іноземна мова": 85}},
    {"піп": "Юлія Мельник", "курс": 1, "група": "1-СОМ", "оцінки": {
        "Вища математика": 91, "Аналітична геометрія": 93, "Історія України": 95, "Інформатика": 90, "Іноземна мова": 92}},
    {"піп": "Андрій Бойко", "курс": 2, "група": "2-СОМ", "оцінки": {
        "Вища математика": 65, "Аналітична геометрія": 70, "Історія України": 60, "Інформатика": 75, "Іноземна мова": 80}},
    {"піп": "Марина Михайлюк", "курс": 3, "група": "3-СОМ", "оцінки": {
        "Вища математика": 87, "Аналітична геометрія": 88, "Історія України": 89, "Інформатика": 86, "Іноземна мова": 90}},
    {"піп": "Денис Савчук", "курс": 1, "група": "1-СОМ", "оцінки": {
        "Вища математика": 92, "Аналітична геометрія": 94, "Історія України": 90, "Інформатика": 91, "Іноземна мова": 93}},
    {"піп": "Ірина Поліщук", "курс": 2, "група": "2-СОМ", "оцінки": {
        "Вища математика": 79, "Аналітична геометрія": 82, "Історія України": 85, "Інформатика": 87, "Іноземна мова": 84}},
    {"піп": "Віктор Романюк", "курс": 1, "група": "1-СОМ", "оцінки": {
        "Вища математика": 100, "Аналітична геометрія": 100, "Історія України": 99, "Інформатика": 100, "Іноземна мова": 98}},
    {"піп": "Катерина Ярошенко", "курс": 3, "група": "3-СОМ", "оцінки": {
        "Вища математика": 85, "Аналітична геометрія": 88, "Історія України": 84, "Інформатика": 86, "Іноземна мова": 87}},
    {"піп": "Олександр Зінченко", "курс": 1, "група": "1-СОМ", "оцінки": {
        "Вища математика": 90, "Аналітична геометрія": 91, "Історія України": 92, "Інформатика": 93, "Іноземна мова": 94}},
    {"піп": "Світлана Рибак", "курс": 2, "група": "2-СОМ", "оцінки": {
        "Вища математика": 77, "Аналітична геометрія": 79, "Історія України": 76, "Інформатика": 78, "Іноземна мова": 75}},
    {"піп": "Назар Гнатюк", "курс": 1, "група": "1-СОМ", "оцінки": {
        "Вища математика": 95, "Аналітична геометрія": 93, "Історія України": 94, "Інформатика": 96, "Іноземна мова": 97}},]


print("Список студентів:\n")
for s in students:
    print(f"{s['піп']} | Курс: {s['курс']} | Група: {s['група']}")
    for subject, mark in s["оцінки"].items():
        print(f"  {subject}: {mark}")
    print()
print("=====================================")


print("Відмінники (всі оцінки від 90 до 100):\n")
for s in students:
    if all(mark >= 90 for mark in s["оцінки"].values()):
        print(f"{s['піп']} | Курс: {s['курс']} | Група: {s['група']}")
        for subject, mark in s["оцінки"].items():
            print(f"  {subject}: {mark}")
        print()
# Out:
# Список студентів:
#
# Іван Петренко | Курс: 1 | Група: 1-СОМ
#   Вища математика: 95
#   Аналітична геометрія: 92
#   Історія України: 88
#   Інформатика: 90
#   Іноземна мова: 93
#
# Олена Коваль | Курс: 2 | Група: 2-СОМ
#   Вища математика: 70
#   Аналітична геометрія: 85
#   Історія України: 78
#   Інформатика: 80
#   Іноземна мова: 76
#
# Микита Шевченко | Курс: 3 | Група: 1-СОМ
#   Вища математика: 98
#   Аналітична геометрія: 96
#   Історія України: 94
#   Інформатика: 99
#   Іноземна мова: 97
#
# Анастасія Бондар | Курс: 2 | Група: 3-СОМ
#   Вища математика: 89
#   Аналітична геометрія: 91
#   Історія України: 93
#   Інформатика: 95
#   Іноземна мова: 90
#
# Сергій Дяченко | Курс: 1 | Група: 1-СОМ
#   Вища математика: 80
#   Аналітична геометрія: 75
#   Історія України: 82
#   Інформатика: 77
#   Іноземна мова: 85
#
# Юлія Мельник | Курс: 1 | Група: 1-СОМ
#   Вища математика: 91
#   Аналітична геометрія: 93
#   Історія України: 95
#   Інформатика: 90
#   Іноземна мова: 92
#
# Андрій Бойко | Курс: 2 | Група: 2-СОМ
#   Вища математика: 65
#   Аналітична геометрія: 70
#   Історія України: 60
#   Інформатика: 75
#   Іноземна мова: 80
#
# Марина Михайлюк | Курс: 3 | Група: 3-СОМ
#   Вища математика: 87
#   Аналітична геометрія: 88
#   Історія України: 89
#   Інформатика: 86
#   Іноземна мова: 90
#
# Денис Савчук | Курс: 1 | Група: 1-СОМ
#   Вища математика: 92
#   Аналітична геометрія: 94
#   Історія України: 90
#   Інформатика: 91
#   Іноземна мова: 93
#
# Ірина Поліщук | Курс: 2 | Група: 2-СОМ
#   Вища математика: 79
#   Аналітична геометрія: 82
#   Історія України: 85
#   Інформатика: 87
#   Іноземна мова: 84
#
# Віктор Романюк | Курс: 1 | Група: 1-СОМ
#   Вища математика: 100
#   Аналітична геометрія: 100
#   Історія України: 99
#   Інформатика: 100
#   Іноземна мова: 98
#
# Катерина Ярошенко | Курс: 3 | Група: 3-СОМ
#   Вища математика: 85
#   Аналітична геометрія: 88
#   Історія України: 84
#   Інформатика: 86
#   Іноземна мова: 87
#
# Олександр Зінченко | Курс: 1 | Група: 1-СОМ
#   Вища математика: 90
#   Аналітична геометрія: 91
#   Історія України: 92
#   Інформатика: 93
#   Іноземна мова: 94
#
# Світлана Рибак | Курс: 2 | Група: 2-СОМ
#   Вища математика: 77
#   Аналітична геометрія: 79
#   Історія України: 76
#   Інформатика: 78
#   Іноземна мова: 75
#
# Назар Гнатюк | Курс: 1 | Група: 1-СОМ
#   Вища математика: 95
#   Аналітична геометрія: 93
#   Історія України: 94
#   Інформатика: 96
#   Іноземна мова: 97
#
# =====================================
# Відмінники (всі оцінки від 90 до 100):
#
# Микита Шевченко | Курс: 3 | Група: 1-СОМ
#   Вища математика: 98
#   Аналітична геометрія: 96
#   Історія України: 94
#   Інформатика: 99
#   Іноземна мова: 97
#
# Юлія Мельник | Курс: 1 | Група: 1-СОМ
#   Вища математика: 91
#   Аналітична геометрія: 93
#   Історія України: 95
#   Інформатика: 90
#   Іноземна мова: 92
#
# Денис Савчук | Курс: 1 | Група: 1-СОМ
#   Вища математика: 92
#   Аналітична геометрія: 94
#   Історія України: 90
#   Інформатика: 91
#   Іноземна мова: 93
#
# Віктор Романюк | Курс: 1 | Група: 1-СОМ
#   Вища математика: 100
#   Аналітична геометрія: 100
#   Історія України: 99
#   Інформатика: 100
#   Іноземна мова: 98
#
# Олександр Зінченко | Курс: 1 | Група: 1-СОМ
#   Вища математика: 90
#   Аналітична геометрія: 91
#   Історія України: 92
#   Інформатика: 93
#   Іноземна мова: 94
#
# Назар Гнатюк | Курс: 1 | Група: 1-СОМ
#   Вища математика: 95
#   Аналітична геометрія: 93
#   Історія України: 94
#   Інформатика: 96
#   Іноземна мова: 97

# %% [markdown]
# ![image.png](data:image/png;base64,...)
